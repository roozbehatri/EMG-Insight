# %% [markdown]
# # 01 — NinaPro DB1 Overview
#
#
# This notebook inspects DB1 files and performs a quick sanity check.
#
# Steps:
# 1. Set `DATA_DIR = '../data/ninapro/db1'`
# 2. Use `load_recording` to read one `.mat`
# 3. Plot a few channels (pre/post filtering) and labels (`Restimulus`)
# 4. Try default `configs/filter_config.yaml`
